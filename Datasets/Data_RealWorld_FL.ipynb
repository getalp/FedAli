# %%
import numpy as np
import os
import pandas as pd
import zipfile
from sklearn.preprocessing import StandardScaler
import hickle as hkl 
import requests 
import urllib.request
from scipy import signal
import tensorflow as tf
import resampy
np.random.seed(0)
# Out:
# 2024-01-16 00:12:13.150106: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-16 00:12:14.801247: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-01-16 00:12:14.801361: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-01-16 00:12:14.801374: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# fomating data to adjust for dataset sensor errors
def formatData(data,dim):
    remainders = data.shape[0]%dim
    max_index = data.shape[0] - remainders
    data = data[:max_index,:]
    new = np.reshape(data, (-1, 128,3))
    return new

# segment data into windows
def segmentData(accData,time_step,step):
#     print(accData.shape)
    segmentAccData = list()
    for i in range(0, accData.shape[0] - time_step,step):
        segmentAccData.append(accData[i:i+time_step,:])
    return np.asarray(segmentAccData)

# load a single file as a numpy array
def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=0,usecols=[2,3,4])
    return dataframe.values
 
# load a list of files, such as x, y, z data for a given variable
def load_group(filenames, filepath='',trainOrEval=0):
    loaded = list()
    for name in filenames:
        data = load_file(filepath + name)
        data = np.asarray(data)
#         print(data.shape)
#         data = segmentData(data,128,64)
        data = np.asarray(data)
        loaded.append(data)
    return loaded

# check if file exist
def isReadableFile(file_path, file_name,flag):
    full_path = file_path + "/" + file_name
    try:
        if not os.path.exists(file_path):
            return False
        elif not os.path.isfile(full_path):
            return False
        elif not os.access(full_path, os.R_OK):
            return False
        else:
            return True
    except IOError as ex:
        print ("I/O error({0}): {1}".format(ex.errno, ex.strerror))
    except Error as ex:
        print ("Error({0}): {1}".format(ex.errno, ex.strerror))
    return False


# stairs down 0 
# stairs Up   1
# jumping     2
# lying       3
# standing    4 
# sitting     5
# running/jogging 6
# Walking     7

# load a dataset group
def load_dataset(group, datasetName='',activity='',orientation='',trainOrEval=0,client = 0):
    filepath = 'dataset/'+datasetName +'/'+ group + '/'
    filenames = list()
    if(isReadableFile('dataset/'+datasetName +'/'+ group, str(client)+'/'+group+'_'+activity+'_'+orientation+'.csv',0)):
        filenames += [str(client)+'/'+group+'_'+activity+'_'+orientation+'.csv']
    if(isReadableFile('dataset/'+datasetName +'/'+ group, str(client)+'/'+group+'_'+activity+'_2_'+orientation+'.csv',1)):
        filenames += [str(client)+'/'+group+'_'+activity+'_2_'+orientation+'.csv']
    if(isReadableFile('dataset/'+datasetName +'/'+ group, str(client)+'/'+group+'_'+activity+'_3_'+orientation+'.csv',1)):
        filenames += [str(client)+'/'+group+'_'+activity+'_3_'+orientation+'.csv']
    X = load_group(filenames, filepath,trainOrEval)
    return X

# download function for datasets
def download_url(url, save_path, chunk_size=128):
    r = requests.get(url, stream=True)
    with open(save_path, 'wb') as fd:
        for chunk in r.iter_content(chunk_size=chunk_size):
            fd.write(chunk)

# %%
# definign activities and orientations of REALWORLD dataset
# activities = ['climbingdown','climbingup','jumping','lying','running','sitting','standing','walking'] 
activities = ['climbingdown','climbingup','running','sitting','standing','walking','lying','jumping']
# activities = ['standing','sitting','walking','climbingup','climbingdown'] 

orientations = ['chest','forearm','head','shin','thigh','upperarm','waist']
# orientations = ['waist']

# %%
orientationKeyMap = dict() 
for index,value in enumerate(orientations):
    orientationKeyMap[value] = index

# %%
# download and unzipping dataset
os.makedirs('dataset',exist_ok=True)
print("downloading...")            
data_directory = os.path.abspath("dataset/realworld2016_dataset.zip")
if not os.path.exists(data_directory):
    download_url("http://wifo5-14.informatik.uni-mannheim.de/sensor/dataset/realworld2016/realworld2016_dataset.zip",data_directory)
    print("download done")
else:
    print("dataset already downloaded")
    
data_directory2 = os.path.abspath("dataset/realworld2016_dataset")
if not os.path.exists(data_directory2): 
    print("extracting data")
    with zipfile.ZipFile(data_directory, 'r') as zip_ref:
        zip_ref.extractall(os.path.abspath(data_directory2))
    print("data extracted in " + data_directory2)
else:
    print("Data already extracted in " + data_directory2)
# Out:
# downloading...
# dataset already downloaded
# Data already extracted in /home/getalp/eks/Projects/FedALP/Datasets/dataset/realworld2016_dataset

# %%
# # unzipping REALWORLD dataset
for id in range(1,16):
    id = str(id)
    for activity in activities:
        for sensor in ["acc","gyr"]:
            dirName = sensor
            if(sensor == "gyr"):
                dirName = "Gyroscope"
            with zipfile.ZipFile('dataset/realworld2016_dataset/proband'+id+'/data/'+sensor+'_'+str(activity)+'_csv.zip', 'r') as zip_ref:
                os.makedirs('dataset/REALWORLD/'+dirName+'/'+id, exist_ok=True)
                zip_ref.extractall('dataset/REALWORLD/'+dirName+'/'+id)

            for i in range (1,4):
                if os.path.exists('dataset/REALWORLD/'+dirName+'/'+id+'/'+sensor+'_'+str(activity)+'_'+str(i)+'_csv.zip'):
                    with zipfile.ZipFile('dataset/REALWORLD/'+dirName+'/'+id+'/'+sensor+'_'+str(activity)+'_'+str(i)+'_csv.zip', 'r') as zip_ref:
                        zip_ref.extractall('dataset/REALWORLD/'+dirName+'/'+id)
                    os.remove('dataset/REALWORLD/'+dirName+'/'+id+'/'+sensor+'_'+str(activity)+'_'+str(i)+'_csv.zip') 
            if os.path.exists('dataset/REALWORLD/'+dirName+'/'+id+'/'+sensor+'_'+str(activity)+'_csv.zip'):
                with zipfile.ZipFile('dataset/REALWORLD/'+dirName+'/'+id+'/'+sensor+'_'+str(activity)+'_csv.zip', 'r') as zip_ref:
                    zip_ref.extractall('dataset/REALWORLD/'+dirName+'/'+id)
                os.remove('dataset/REALWORLD/'+dirName+'/'+id+'/'+sensor+'_'+str(activity)+'_csv.zip')

# %%
def downSampleLowPass(toDownSampleData,factor):
    accX = signal.decimate(toDownSampleData[:,0],factor)
    accY = signal.decimate(toDownSampleData[:,1],factor)
    accZ = signal.decimate(toDownSampleData[:,2],factor)
    return np.dstack((accX,accY,accZ)).squeeze()

# %%
# Reading and processing all data
xAccListClient = list()
xGyrListClient = list()
yListClient = list()

xAccListWatchClient = list()
xGyrListWatchClient = list()
yListWatchClient = list()
nbAnomalies = 0 
for k in range(1,16):
    for orientation in orientations:
        xAccList = list()
        xGyrList = list()
        yList = list()
        for activity in activities:
            tempAcc = load_dataset('acc','REALWORLD',activity,orientation,0,k)
            tempGyro = load_dataset('Gyroscope','REALWORLD',activity,orientation,0,k)
            orientationLength = 0 
            for i in range(0, len(tempAcc)):  
                accDataLength = len(tempAcc[i])
                gyroDataLength = len(tempGyro[i])
                difference = accDataLength - gyroDataLength
                differenceAbs = abs(difference)


                differenceAcc = accDataLength - gyroDataLength
                differenceGyro = gyroDataLength - accDataLength
                if(differenceGyro > 100):
                    print("Client Number "+str(k) +" Activity : "+str(activity) + " Orientation :"+str(orientation))
                    print("Disalignment of:" +str(differenceAbs) + " found")
                    print("Acc data: "+str(accDataLength))
                    print("Gyro data: "+str(gyroDataLength))
                    tempGyro[i] = resampy.resample(tempGyro[i], gyroDataLength, accDataLength,axis = 0)
                elif(differenceAcc > 100):
                    print("Client Number "+str(k) +" Activity : "+str(activity) + " Orientation :"+str(orientation))
                    print("Disalignment of:" +str(differenceAbs) + " found")
                    print("Acc data: "+str(accDataLength))
                    print("Gyro data: "+str(gyroDataLength))
                    tempGyro[i] = resampy.resample(tempAcc[i], accDataLength, gyroDataLength,axis = 0)
                tempAcc[i] = segmentData(tempAcc[i],128,64)
                tempGyro[i] = segmentData(tempGyro[i],128,64)
    
                accDataLength = len(tempAcc[i])
                gyroDataLength = len(tempGyro[i])
    
                difference = accDataLength - gyroDataLength
                differenceAbs = abs(difference)
                if(differenceAbs <= 10):
                    toAddShape = 0
                    if(difference > 0):
                        maxIndex = accDataLength-differenceAbs
                        xAccList.append(tempAcc[i][:maxIndex,:])
                        xGyrList.append(tempGyro[i])
                        toAddShape = tempGyro[i].shape[0]
                        yList.append(np.full((toAddShape), activities.index(activity)))   
                    else:
                        maxIndex = gyroDataLength-differenceAbs
                        xAccList.append(tempAcc[i])
                        xGyrList.append(tempGyro[i][:maxIndex,:])
                        toAddShape = tempAcc[i].shape[0]
                        yList.append(np.full((toAddShape), activities.index(activity)))
                else:
                    print("Difference: "+str(differenceAbs))
                    print("Big misalignment, skipping")
        if(orientation == 'forearm'):
            xAccListWatchClient.append(np.vstack((xAccList)))
            xGyrListWatchClient.append(np.vstack((xGyrList)))
            yListWatchClient.append(np.hstack((yList)))
        else:
            xAccListClient.append(np.vstack((xAccList)))
            xGyrListClient.append(np.vstack((xGyrList)))
            yListClient.append(np.hstack((yList)))
# Out:
# Client Number 1 Activity : climbingup Orientation :chest
# Disalignment of:90903 found
# Acc data: 32863
# Gyro data: 123766
# Client Number 1 Activity : climbingdown Orientation :forearm
# Disalignment of:505 found
# Acc data: 25281
# Gyro data: 25786
# Client Number 1 Activity : climbingup Orientation :forearm
# Disalignment of:8595 found
# Acc data: 26938
# Gyro data: 18343
# Difference: 134
# Big misalignment, skipping
# Client Number 1 Activity : running Orientation :forearm
# Disalignment of:529 found
# Acc data: 30429
# Gyro data: 30958
# Client Number 1 Activity : sitting Orientation :forearm
# Disalignment of:434 found
# Acc data: 32833
# Gyro data: 33267
# Client Number 1 Activity : standing Orientation :forearm
# Disalignment of:622 found
# Acc data: 31924
# Gyro data: 32546
# Client Number 1 Activity : walking Orientation :forearm
# Disalignment of:119 found
# Acc data: 31793
# Gyro data: 31912
# Client Number 1 Activity : lying Orientation :forearm
# Disalignment of:593 found
# Acc data: 31229
# Gyro data: 31822
# Client Number 1 Activity : sitting Orientation :shin
# Disalignment of:59309 found
# Acc data: 32877
# Gyro data: 92186
# Client Number 1 Activity : sitting Orientation :waist
# Disalignment of:42063 found
# Acc data: 32875
# Gyro data: 74938
# Client Number 1 Activity : lying Orientation :waist
# Disalignment of:29601 found
# Acc data: 33237
# Gyro data: 62838
# Client Number 2 Activity : running Orientation :chest
# Disalignment of:18983 found
# Acc data: 30655
# Gyro data: 49638
# Client Number 2 Activity : standing Orientation :chest
# Disalignment of:52189 found
# Acc data: 30769
# Gyro data: 82958
# Client Number 2 Activity : lying Orientation :chest
# Disalignment of:66040 found
# Acc data: 31050
# Gyro data: 97090
# Client Number 2 Activity : jumping Orientation :chest
# Disalignment of:12938 found
# Acc data: 4756
# Gyro data: 17694
# Client Number 2 Activity : climbingdown Orientation :forearm
# Disalignment of:461 found
# Acc data: 24676
# Gyro data: 25137
# Client Number 2 Activity : running Orientation :forearm
# Disalignment of:8245 found
# Acc data: 16456
# Gyro data: 8211
# Difference: 129
# Big misalignment, skipping
# Client Number 2 Activity : sitting Orientation :forearm
# Disalignment of:596 found
# Acc data: 30683
# Gyro data: 31279
# Client Number 2 Activity : standing Orientation :forearm
# Disalignment of:511 found
# Acc data: 30583
# Gyro data: 31094
# Client Number 2 Activity : walking Orientation :forearm
# Disalignment of:541 found
# Acc data: 30559
# Gyro data: 31100
# Client Number 2 Activity : lying Orientation :forearm
# Disalignment of:565 found
# Acc data: 30861
# Gyro data: 31426
# Client Number 3 Activity : climbingup Orientation :forearm
# Disalignment of:226 found
# Acc data: 29723
# Gyro data: 29949
# Client Number 3 Activity : running Orientation :forearm
# Disalignment of:651 found
# Acc data: 37708
# Gyro data: 38359
# Client Number 3 Activity : sitting Orientation :forearm
# Disalignment of:541 found
# Acc data: 31352
# Gyro data: 31893
# Client Number 3 Activity : standing Orientation :forearm
# Disalignment of:506 found
# Acc data: 31054
# Gyro data: 31560
# Client Number 3 Activity : walking Orientation :forearm
# Disalignment of:648 found
# Acc data: 33910
# Gyro data: 34558
# Client Number 3 Activity : lying Orientation :forearm
# Disalignment of:588 found
# Acc data: 31379
# Gyro data: 31967
# Client Number 4 Activity : climbingdown Orientation :chest
# Disalignment of:27708 found
# Acc data: 11089
# Gyro data: 38797
# Client Number 4 Activity : climbingup Orientation :chest
# Disalignment of:20402 found
# Acc data: 11676
# Gyro data: 32078
# Client Number 4 Activity : running Orientation :chest
# Disalignment of:139657 found
# Acc data: 52180
# Gyro data: 191837
# Client Number 4 Activity : climbingdown Orientation :forearm
# Disalignment of:231 found
# Acc data: 11237
# Gyro data: 11468
# Client Number 4 Activity : climbingup Orientation :forearm
# Disalignment of:222 found
# Acc data: 11651
# Gyro data: 11873
# Client Number 4 Activity : climbingup Orientation :forearm
# Disalignment of:269 found
# Acc data: 14054
# Gyro data: 14323
# Client Number 4 Activity : climbingup Orientation :forearm
# Disalignment of:251 found
# Acc data: 13058
# Gyro data: 13309
# Client Number 4 Activity : running Orientation :forearm
# Disalignment of:772 found
# Acc data: 51914
# Gyro data: 52686
# Client Number 4 Activity : sitting Orientation :forearm
# Disalignment of:628 found
# Acc data: 31626
# Gyro data: 32254
# Client Number 4 Activity : standing Orientation :forearm
# Disalignment of:600 found
# Acc data: 30057
# Gyro data: 30657
# Client Number 4 Activity : walking Orientation :forearm
# Disalignment of:556 found
# Acc data: 30842
# Gyro data: 31398
# Client Number 4 Activity : lying Orientation :forearm
# Disalignment of:589 found
# Acc data: 33607
# Gyro data: 34196
# Client Number 5 Activity : climbingdown Orientation :forearm
# Disalignment of:385 found
# Acc data: 25186
# Gyro data: 25571
# Client Number 5 Activity : climbingup Orientation :forearm
# Disalignment of:328 found
# Acc data: 30274
# Gyro data: 30602
# Client Number 5 Activity : running Orientation :forearm
# Disalignment of:320 found
# Acc data: 55569
# Gyro data: 55889
# Client Number 5 Activity : sitting Orientation :forearm
# Disalignment of:597 found
# Acc data: 32570
# Gyro data: 33167
# Client Number 5 Activity : standing Orientation :forearm
# Disalignment of:402 found
# Acc data: 29858
# Gyro data: 30260
# Client Number 5 Activity : walking Orientation :forearm
# Disalignment of:483 found
# Acc data: 34625
# Gyro data: 35108
# Client Number 5 Activity : lying Orientation :forearm
# Disalignment of:385 found
# Acc data: 33008
# Gyro data: 33393
# Client Number 6 Activity : climbingup Orientation :chest
# Disalignment of:70838 found
# Acc data: 25950
# Gyro data: 96788
# Client Number 6 Activity : climbingdown Orientation :forearm
# Disalignment of:315 found
# Acc data: 24566
# Gyro data: 24881
# Client Number 6 Activity : climbingup Orientation :forearm
# Disalignment of:321 found
# Acc data: 25793
# Gyro data: 26114
# Client Number 6 Activity : running Orientation :forearm
# Disalignment of:392 found
# Acc data: 33066
# Gyro data: 33458
# Client Number 6 Activity : sitting Orientation :forearm
# Disalignment of:611 found
# Acc data: 32768
# Gyro data: 33379
# Client Number 6 Activity : standing Orientation :forearm
# Disalignment of:483 found
# Acc data: 31626
# Gyro data: 32109
# Client Number 6 Activity : walking Orientation :forearm
# Disalignment of:236 found
# Acc data: 31365
# Gyro data: 31601
# Client Number 6 Activity : lying Orientation :forearm
# Disalignment of:616 found
# Acc data: 32013
# Gyro data: 32629
# Client Number 7 Activity : climbingdown Orientation :chest
# Disalignment of:19811 found
# Acc data: 9671
# Gyro data: 29482
# Client Number 7 Activity : climbingdown Orientation :chest
# Disalignment of:20389 found
# Acc data: 10042
# Gyro data: 30431
# Client Number 7 Activity : climbingdown Orientation :chest
# Disalignment of:18327 found
# Acc data: 9172
# Gyro data: 27499
# Client Number 7 Activity : climbingup Orientation :chest
# Disalignment of:29877 found
# Acc data: 11254
# Gyro data: 41131
# Client Number 7 Activity : climbingup Orientation :chest
# Disalignment of:19398 found
# Acc data: 10490
# Gyro data: 29888
# Client Number 7 Activity : climbingup Orientation :chest
# Disalignment of:11908 found
# Acc data: 10250
# Gyro data: 22158
# Client Number 7 Activity : walking Orientation :chest
# Disalignment of:82463 found
# Acc data: 30905
# Gyro data: 113368
# Client Number 7 Activity : climbingdown Orientation :forearm
# Disalignment of:179 found
# Acc data: 9612
# Gyro data: 9791
# Client Number 7 Activity : climbingdown Orientation :forearm
# Disalignment of:190 found
# Acc data: 9980
# Gyro data: 10170
# Client Number 7 Activity : climbingdown Orientation :forearm
# Disalignment of:172 found
# Acc data: 9115
# Gyro data: 9287
# Client Number 7 Activity : climbingup Orientation :forearm
# Disalignment of:191 found
# Acc data: 11185
# Gyro data: 11376
# Client Number 7 Activity : climbingup Orientation :forearm
# Disalignment of:191 found
# Acc data: 10426
# Gyro data: 10617
# Client Number 7 Activity : climbingup Orientation :forearm
# Disalignment of:188 found
# Acc data: 10188
# Gyro data: 10376
# Client Number 7 Activity : running Orientation :forearm
# Disalignment of:617 found
# Acc data: 36552
# Gyro data: 37169
# Client Number 7 Activity : sitting Orientation :forearm
# Disalignment of:385 found
# Acc data: 32346
# Gyro data: 32731
# Client Number 7 Activity : standing Orientation :forearm
# Disalignment of:597 found
# Acc data: 32940
# Gyro data: 33537
# Client Number 7 Activity : walking Orientation :forearm
# Disalignment of:543 found
# Acc data: 30718
# Gyro data: 31261
# Client Number 7 Activity : lying Orientation :forearm
# Disalignment of:576 found
# Acc data: 32443
# Gyro data: 33019
# Client Number 8 Activity : climbingup Orientation :chest
# Disalignment of:120501 found
# Acc data: 57853
# Gyro data: 178354
# Client Number 8 Activity : lying Orientation :chest
# Disalignment of:27685 found
# Acc data: 31654
# Gyro data: 59339
# Client Number 8 Activity : climbingdown Orientation :forearm
# Disalignment of:446 found
# Acc data: 21965
# Gyro data: 22411
# Client Number 8 Activity : climbingup Orientation :forearm
# Disalignment of:1002 found
# Acc data: 57528
# Gyro data: 58530
# Client Number 8 Activity : running Orientation :forearm
# Disalignment of:565 found
# Acc data: 30683
# Gyro data: 31248
# Client Number 8 Activity : sitting Orientation :forearm
# Disalignment of:509 found
# Acc data: 32505
# Gyro data: 33014
# Client Number 8 Activity : standing Orientation :forearm
# Disalignment of:514 found
# Acc data: 31978
# Gyro data: 32492
# Client Number 8 Activity : walking Orientation :forearm
# Disalignment of:565 found
# Acc data: 32709
# Gyro data: 33274
# Client Number 8 Activity : lying Orientation :forearm
# Disalignment of:530 found
# Acc data: 31450
# Gyro data: 31980
# Client Number 9 Activity : climbingup Orientation :chest
# Disalignment of:30738 found
# Acc data: 27298
# Gyro data: 58036
# Client Number 9 Activity : climbingdown Orientation :forearm
# Disalignment of:476 found
# Acc data: 24860
# Gyro data: 25336
# Client Number 9 Activity : climbingup Orientation :forearm
# Disalignment of:561 found
# Acc data: 27127
# Gyro data: 27688
# Client Number 9 Activity : running Orientation :forearm
# Disalignment of:768 found
# Acc data: 40692
# Gyro data: 41460
# Client Number 9 Activity : sitting Orientation :forearm
# Disalignment of:671 found
# Acc data: 32271
# Gyro data: 32942
# Client Number 9 Activity : standing Orientation :forearm
# Disalignment of:648 found
# Acc data: 31974
# Gyro data: 32622
# Client Number 9 Activity : walking Orientation :forearm
# Disalignment of:599 found
# Acc data: 31204
# Gyro data: 31803
# Client Number 9 Activity : lying Orientation :forearm
# Disalignment of:512 found
# Acc data: 31278
# Gyro data: 31790
# Client Number 9 Activity : jumping Orientation :forearm
# Disalignment of:103 found
# Acc data: 5043
# Gyro data: 5146
# Client Number 10 Activity : standing Orientation :chest
# Disalignment of:24932 found
# Acc data: 33068
# Gyro data: 58000
# Client Number 10 Activity : climbingdown Orientation :forearm
# Disalignment of:329 found
# Acc data: 21800
# Gyro data: 22129
# Client Number 10 Activity : climbingup Orientation :forearm
# Disalignment of:107 found
# Acc data: 22841
# Gyro data: 22948
# Client Number 10 Activity : running Orientation :forearm
# Disalignment of:461 found
# Acc data: 32024
# Gyro data: 32485
# Client Number 10 Activity : sitting Orientation :forearm
# Disalignment of:523 found
# Acc data: 31933
# Gyro data: 32456
# Client Number 10 Activity : standing Orientation :forearm
# Disalignment of:567 found
# Acc data: 32868
# Gyro data: 33435
# Client Number 10 Activity : walking Orientation :forearm
# Disalignment of:480 found
# Acc data: 31577
# Gyro data: 32057
# Client Number 10 Activity : lying Orientation :forearm
# Disalignment of:295 found
# Acc data: 32033
# Gyro data: 32328
# Client Number 11 Activity : sitting Orientation :chest
# Disalignment of:16193 found
# Acc data: 31336
# Gyro data: 47529
# Client Number 11 Activity : running Orientation :forearm
# Disalignment of:557 found
# Acc data: 30896
# Gyro data: 31453
# Client Number 11 Activity : sitting Orientation :forearm
# Disalignment of:496 found
# Acc data: 31146
# Gyro data: 31642
# Client Number 11 Activity : standing Orientation :forearm
# Disalignment of:401 found
# Acc data: 31433
# Gyro data: 31834
# Client Number 11 Activity : walking Orientation :forearm
# Disalignment of:600 found
# Acc data: 33095
# Gyro data: 33695
# Client Number 11 Activity : lying Orientation :forearm
# Disalignment of:605 found
# Acc data: 32579
# Gyro data: 33184
# Client Number 12 Activity : climbingup Orientation :chest
# Disalignment of:66571 found
# Acc data: 28018
# Gyro data: 94589
# Client Number 12 Activity : climbingdown Orientation :forearm
# Disalignment of:289 found
# Acc data: 24241
# Gyro data: 24530
# Client Number 12 Activity : climbingup Orientation :forearm
# Disalignment of:553 found
# Acc data: 27849
# Gyro data: 28402
# Client Number 12 Activity : running Orientation :forearm
# Disalignment of:557 found
# Acc data: 30788
# Gyro data: 31345
# Client Number 12 Activity : sitting Orientation :forearm
# Disalignment of:646 found
# Acc data: 31149
# Gyro data: 31795
# Client Number 12 Activity : standing Orientation :forearm
# Disalignment of:613 found
# Acc data: 30682
# Gyro data: 31295
# Client Number 12 Activity : walking Orientation :forearm
# Disalignment of:575 found
# Acc data: 31557
# Gyro data: 32132
# Client Number 12 Activity : lying Orientation :forearm
# Disalignment of:557 found
# Acc data: 31109
# Gyro data: 31666
# Client Number 13 Activity : climbingup Orientation :forearm
# Disalignment of:523 found
# Acc data: 29878
# Gyro data: 30401
# Client Number 13 Activity : running Orientation :forearm
# Disalignment of:510 found
# Acc data: 30797
# Gyro data: 31307
# Client Number 13 Activity : sitting Orientation :forearm
# Disalignment of:659 found
# Acc data: 32128
# Gyro data: 32787
# Client Number 13 Activity : standing Orientation :forearm
# Disalignment of:586 found
# Acc data: 33861
# Gyro data: 34447
# Client Number 13 Activity : walking Orientation :forearm
# Disalignment of:521 found
# Acc data: 32594
# Gyro data: 33115
# Client Number 13 Activity : lying Orientation :forearm
# Disalignment of:463 found
# Acc data: 32226
# Gyro data: 32689
# Client Number 14 Activity : climbingdown Orientation :chest
# Disalignment of:19498 found
# Acc data: 7332
# Gyro data: 26830
# Client Number 14 Activity : climbingdown Orientation :chest
# Disalignment of:15583 found
# Acc data: 6838
# Gyro data: 22421
# Client Number 14 Activity : climbingdown Orientation :chest
# Disalignment of:18395 found
# Acc data: 6893
# Gyro data: 25288
# Client Number 14 Activity : climbingup Orientation :chest
# Disalignment of:10479 found
# Acc data: 9921
# Gyro data: 20400
# Client Number 14 Activity : climbingup Orientation :chest
# Disalignment of:2690 found
# Acc data: 9641
# Gyro data: 12331
# Client Number 14 Activity : walking Orientation :chest
# Disalignment of:42822 found
# Acc data: 33577
# Gyro data: 76399
# Client Number 14 Activity : climbingdown Orientation :forearm
# Disalignment of:140 found
# Acc data: 7288
# Gyro data: 7428
# Client Number 14 Activity : climbingdown Orientation :forearm
# Disalignment of:127 found
# Acc data: 6741
# Gyro data: 6868
# Client Number 14 Activity : climbingdown Orientation :forearm
# Disalignment of:123 found
# Acc data: 6851
# Gyro data: 6974
# Client Number 14 Activity : climbingup Orientation :forearm
# Disalignment of:214 found
# Acc data: 11519
# Gyro data: 11733
# Client Number 14 Activity : climbingup Orientation :forearm
# Disalignment of:161 found
# Acc data: 9860
# Gyro data: 10021
# Client Number 14 Activity : climbingup Orientation :forearm
# Disalignment of:169 found
# Acc data: 9582
# Gyro data: 9751
# Client Number 14 Activity : running Orientation :forearm
# Disalignment of:567 found
# Acc data: 30852
# Gyro data: 31419
# Client Number 14 Activity : sitting Orientation :forearm
# Disalignment of:650 found
# Acc data: 31378
# Gyro data: 32028
# Client Number 14 Activity : standing Orientation :forearm
# Disalignment of:591 found
# Acc data: 31032
# Gyro data: 31623
# Client Number 14 Activity : walking Orientation :forearm
# Disalignment of:705 found
# Acc data: 33374
# Gyro data: 34079
# Client Number 14 Activity : lying Orientation :forearm
# Disalignment of:611 found
# Acc data: 31358
# Gyro data: 31969
# Client Number 14 Activity : climbingdown Orientation :upperarm
# Disalignment of:7544 found
# Acc data: 7331
# Gyro data: 14875
# Client Number 15 Activity : climbingdown Orientation :forearm
# Disalignment of:464 found
# Acc data: 25444
# Gyro data: 25908
# Client Number 15 Activity : climbingup Orientation :forearm
# Disalignment of:463 found
# Acc data: 29084
# Gyro data: 29547
# Client Number 15 Activity : running Orientation :forearm
# Disalignment of:621 found
# Acc data: 33587
# Gyro data: 34208
# Client Number 15 Activity : sitting Orientation :forearm
# Disalignment of:651 found
# Acc data: 32073
# Gyro data: 32724
# Client Number 15 Activity : standing Orientation :forearm
# Disalignment of:601 found
# Acc data: 31277
# Gyro data: 31878
# Client Number 15 Activity : walking Orientation :forearm
# Disalignment of:589 found
# Acc data: 33016
# Gyro data: 33605
# Client Number 15 Activity : lying Orientation :forearm
# Disalignment of:624 found
# Acc data: 32882
# Gyro data: 33506

# %%
def normalizedData(accData, gyroData):
    allAcc = np.vstack((accData))
    allGyro = np.vstack((gyroData))
    
    # Calculating features
    meanAcc = np.mean(allAcc)
    stdAcc = np.std(allAcc)
    meanGyro = np.mean(allGyro)
    stdGyro = np.std(allGyro)


    numpyAccData = np.asarray(accData, dtype=object)
    numpyGyroData = np.asarray(gyroData, dtype=object)
    normalizedAcc = (numpyAccData - meanAcc)/stdAcc
    normalizedGyro = (numpyGyroData - meanGyro)/stdGyro

    subjectData = np.asarray([np.dstack((normAcc,normGyro))for normAcc,normGyro in zip(normalizedAcc,normalizedGyro)],dtype=object)
    return subjectData

# %%
subjectData = normalizedData(xAccListClient,xGyrListClient)

# %%
subjectWatchData = normalizedData(xAccListWatchClient,xGyrListWatchClient)

# %%
yListClient = np.asarray(yListClient, dtype=object)
yListWatchClient = np.asarray(yListWatchClient, dtype=object)

# %%
allLabels = np.hstack((yListClient,yListWatchClient))
allData =  np.hstack((subjectData,subjectWatchData))

# %%
dataName = 'RealWorld'
os.makedirs('processedDatasets/'+dataName, exist_ok=True)
hkl.dump(allData,'processedDatasets/'+dataName+ '/clientsData.hkl' )
hkl.dump(allLabels,'processedDatasets/'+dataName+ '/clientsLabel.hkl' )
